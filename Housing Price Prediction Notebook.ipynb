# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv("kc_house_data.csv")

# %%
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
dataset.keys()
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
dataset.keys()
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# # Remove target variable 'price' separat from the dataset

# %%
target = dataset.pop('price')

# %%
target.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
dataset.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013T000000         3       1.00         1180      5650
# 1  6414100192  20141209T000000         3       2.25         2570      7242
# 2  5631500400  20150225T000000         2       1.00          770     10000
# 3  2487200875  20141209T000000         4       3.00         1960      5000
# 4  1954400510  20150218T000000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# # Check dataset information

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  zipcode        21613 non-null  int64
#  16  lat            21613 non-null  float64
# ...

# %% [markdown]
# ## Check for null values

# %%
dataset.isnull().sum()
# Out:
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
target.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Adding price again to check the correlation

# %%
dataset['price'] = target

# %%
dataset.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013T000000         3       1.00         1180      5650
# 1  6414100192  20141209T000000         3       2.25         2570      7242
# 2  5631500400  20150225T000000         2       1.00          770     10000
# 3  2487200875  20141209T000000         4       3.00         1960      5000
# 4  1954400510  20150218T000000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 0     1.0           0     0          3  ...        1180              0
# 1     2.0           0     0          3  ...        2170            400
# 2     1.0           0     0          3  ...         770              0
# 3     1.0           0     0          5  ...        1050            910
# 4     1.0           0     0          3  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# ## Correlation

# %%
dataset.corr()
# Out:
#                      id  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# id             1.000000  0.001286   0.005160    -0.012258 -0.132109  0.018525
# bedrooms       0.001286  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.005160  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living   -0.012258  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot      -0.132109  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.018525  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront    -0.002721 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.011592  0.079532   0.187737     0.284611  0.074710  0.029444
# condition     -0.023783  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.008130  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above    -0.010842  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %% [markdown]
# ##### If correlation is less that 0.1, then drop those columns. Hence, ['id', 'sqft_lot', 'condition', 'yr_built', 'zipcode', 'long', 'sqft_lot15'] these colums will be deleted

# %%
dataset.pop('price')
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
dataset.pop('date')
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21608    20140521T000000
# 21609    20150223T000000
# 21610    20140623T000000
# 21611    20150116T000000
# 21612    20141015T000000
# Name: date, Length: 21613, dtype: object

# %%
dataset.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013T000000         3       1.00         1180      5650
# 1  6414100192  20141209T000000         3       2.25         2570      7242
# 2  5631500400  20150225T000000         2       1.00          770     10000
# 3  2487200875  20141209T000000         4       3.00         1960      5000
# 4  1954400510  20150218T000000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# ## id is removed

# %%
dataset.pop('id')
# Out:
# 0        7129300520
# 1        6414100192
# 2        5631500400
# 3        2487200875
# 4        1954400510
#             ...
# 21608     263000018
# 21609    6600060120
# 21610    1523300141
# 21611     291310100
# 21612    1523300157
# Name: id, Length: 21613, dtype: int64

# %%
plt.scatter(target, dataset['sqft_living'])
plt.xlabel('price')
plt.ylabel('sqft_living')
# Out:
# Text(0, 0.5, 'sqft_living')

# %% [markdown]
# ## Model Training

# %%
## Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset, target, test_size = 0.20, random_state = 42)

# %%
print("X_train shape is:", X_train.shape)
print("X_test shape is:", X_test.shape)
print("y_train shape is:", y_train.shape)
print("y_test shape is:", y_test.shape)
# Out:
# X_train shape is: (17290, 18)
# X_test shape is: (4323, 18)
# y_train shape is: (17290,)
# y_test shape is: (4323,)

# %% [markdown]
# ## Standardization of Data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.fit_transform(X_test)

# %%
import pickle
pickle.dump(scaler, open('scaling.pkl', 'wb'))

# %%
X_train
# Out:
# array([[-0.39526335, -0.47445144, -0.32393262, ...,  0.44228847,
#          1.12607326,  0.01344043],
#        [-1.46896378, -1.45258323, -1.18365301, ..., -0.53995821,
#         -1.04652268, -0.28066159],
#        [-0.39526335, -1.45258323, -1.09547656, ..., -0.86025604,
#         -1.19331971, -0.1789339 ],
#        ...,
#        [-0.39526335,  0.50368036,  0.05081729, ...,  1.29641601,
#         -0.42997519, -0.36604019],
#        [-2.54266422, -1.77862716, -1.8670205 , ..., -0.77484328,
#         -1.19331971,  0.08265159],
#        [ 0.67843709,  0.50368036,  1.16404497, ...,  0.81952813,
#          1.52242522, -0.24443927]])

# %%
X_test
# Out:
# array([[ 0.6686932 ,  0.16769731, -0.03528019, ...,  0.35829093,
#          0.55425337, -0.19855534],
#        [ 1.75015997,  1.12494485,  0.82809787, ..., -0.50707458,
#          0.52574661, -0.25222795],
#        [ 0.6686932 ,  0.48677982,  1.73308451, ...,  0.59046216,
#          2.43569951, -0.12336824],
#        ...,
#        [ 0.6686932 ,  0.48677982,  0.3433579 , ..., -0.49300359,
#          0.61696825, -0.32355153],
#        [ 0.6686932 , -0.47046772,  0.15195843, ...,  0.66785257,
#          0.06963846, -0.12090619],
#        [ 0.6686932 ,  0.48677982,  0.48482708, ..., -0.58446499,
#          0.61126689, -0.26306095]])

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [-31978.58324666  34170.64740325  80144.32815078   3450.66466526
#    3801.31859972  47457.6040034   40859.88011873  15983.53629513
#  110674.78779944  74521.83743949  26179.5650669  -78907.76799812
#    8135.46077341 -29448.64012297  82498.66055167 -27338.17336913
#   14451.47195385  -8968.34709633]

# %%
print(regression.intercept_)
# Out:
# 537768.0479467959

# %%
### Parameters on which model is trained
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
reg_pred = regression.predict(X_test)
reg_pred
# Out:
# array([ 452814.469988  ,  737061.51821544, 1204452.3878387 , ...,
#         410385.15873341,  608090.08754511,  428307.15782966])

# %%
plt.scatter(y_test, reg_pred)

# %%
## Residulas
residuals = y_test - reg_pred
residuals
# Out:
# 735      -87814.469988
# 2830     127938.481785
# 4106    -166452.387839
# 16218   -128598.840406
# 19964     -8492.858320
#              ...
# 13674   -140833.964018
# 20377     73957.256816
# 8805    -125385.158733
# 10168     -3090.087545
# 2522     -71807.157830
# Name: price, Length: 4323, dtype: float64

# %%
## Plot the residual 
import seaborn as sns
sns.displot(residuals, kind = "kde")

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 125222.29566827643
# 45698165288.55128
# 213771.29201216725

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.6977168996048289

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6964527044823583

# %% [markdown]
# ## New Data Prediction

# %%
np.array(dataset[0:1])
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          0.00000e+00,  9.81780e+04,  4.75112e+01, -1.22257e+02,
#          1.34000e+03,  5.65000e+03]])

# %%
scaler.transform(np.array(dataset[0:1]))
# Out:
# C:\Users\LALIT\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.41277358, -1.42771526, -0.96107112, -0.21199202, -0.89930683,
#         -0.095413  , -0.30526145, -0.64440723, -0.55954584, -0.72429484,
#         -0.66864566, -0.53545925, -0.21733662,  1.84818426, -0.34327875,
#         -0.3100808 , -0.94235151, -0.27620449]])

# %%
regression.predict(scaler.transform(np.array(dataset[0:1])))
# Out:
# C:\Users\LALIT\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([215371.35030514])

# %%
target[0]
# Out:
# 221900.0

# %% [markdown]
# ## Pickling the Model for Deployment

# %%
import pickle

# %%
pickle.dump(regression, open('regression.pkl', 'wb'))

# %%
pickled_model = pickle.load(open('regression.pkl', 'rb'))

# %%
## Prediction
pickled_model.predict(scaler.transform(np.array(dataset[0:1])))
# Out:
# C:\Users\LALIT\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([215371.35030514])
